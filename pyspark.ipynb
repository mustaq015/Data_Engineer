# %% [markdown]
# <a href="https://colab.research.google.com/github/mustaq015/Data_Engineer/blob/main/pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.3/455.3 MB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-4.1.0-py2.py3-none-any.whl size=455986223 sha256=841b6c6e3f8d342c0d1c9c59de4d3e43f14b0e2d43fb62c8a67feb2965686ad9
#   Stored in directory: /root/.cache/pip/wheels/6b/9b/7c/2bea6ee44c4721d1af223365b8ab673a2db3ed4b759c12439d
# Successfully built pyspark
# ...

# %%
import pyspark
pyspark.__version__
# Out:
# '4.1.0'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Demo').getOrCreate()

# %%
data =[(1, 'MustaqAhmed'), (2, 'Musaib'), (3, 'Adnan')]
columns = ['Id', 'Name']

df = spark.createDataFrame(data, columns)
df.show()
df.printSchema()
# Out:
# +---+-----------+
# | Id|       Name|
# +---+-----------+
# |  1|MustaqAhmed|
# |  2|     Musaib|
# |  3|      Adnan|
# +---+-----------+
#
# root
#  |-- Id: long (nullable = true)
#  |-- Name: string (nullable = true)
